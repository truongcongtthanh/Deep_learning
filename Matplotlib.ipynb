# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1, 2, 3, 5]
y = [4, 5, 6, 7]

x1 =  np.arange(10)
y1 = np.random.randint(0,1023,size = 10)
plt.plot(x1, y1, linestyle='--', color='b')
# Một cách ngắn hơn 
plt.plot(x1, y1, 'ro')
plt.show()
